# %% [markdown]
# <a href="https://colab.research.google.com/github/levelolos/datascience1/blob/main/ML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets

# %%
diabetes = datasets.load_diabetes()
X = diabetes.data
Y = diabetes.target
Z = diabetes.feature_names

# %%
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
X.shape
# Out:
# (442, 10)

# %%
import pandas as pd
df = pd.DataFrame(X, columns = Z)
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %%
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y)
print(X.shape)
print(X_train.shape, X_test.shape)
print(Y_train.shape, Y_test.shape)
# Out:
# (442, 10)
# (331, 10) (111, 10)
# (331,) (111,)

# %%
from sklearn.linear_model import LinearRegression
alg1 = LinearRegression()

# %%
alg1.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pre = alg1.predict(X_test)
y_pre
# now we have to comapre y predicted with y test
# Out:
# array([162.10774332, 229.65748013, 212.67552707, 100.02882742,
#        189.13412639, 190.42217237, 182.89258162, 233.2301975 ,
#        235.23541944, 107.4703179 , 140.33992929, 153.52270357,
#        120.61004473, 123.68861117, 191.10782035, 164.03395096,
#        197.61954059, 261.02434007, 212.7318426 , 188.209818  ,
#        246.53442218, 117.96401818,  81.36665355, 177.01705496,
#         73.74612929,  40.99710738, 188.8827722 , 146.98798012,
#        159.00581999, 121.9958467 , 102.80922347, 191.71253298,
#        306.12226872, 130.76252925, 205.8247427 , 120.90366648,
#        128.45482814, 130.70641099, 148.74090223, 137.50048663,
#        110.32434133,  54.84664317, 122.33970344, 218.01370239,
#        147.62871151, 153.15538025, 211.44449395, 219.35851957,
#        160.58175379, 210.99612383, 200.70948258, 149.91312747,
#        132.62062508, 151.07013428, 100.99775438,  81.27744511,
#        133.07698627, 181.18515527, 295.59858646, 203.46760969,
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(Y_test, y_pre)
