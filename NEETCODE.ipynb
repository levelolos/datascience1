# %% [markdown]
# ![image.png](attachment:4422fe6b-8b9d-43c4-8f51-ed850db16fcf.png)

# %%
a = [1,2,3]
b = a * 2
print(b)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
class Solution(object):
    def getConcatenation(self, nums):
        return nums * 2

# %% [markdown]
# ![image.png](attachment:0bcc25ba-2641-4a7d-aacf-286cbf955c5b.png)

# %%
s = "123456"
t = "nagrama"
w = []
for a in s:
    w.append(int(a))
print(sum(w))
# Out:
# 21

# %% [markdown]
# ## Dictionary

# %%
rollno = {1:"aman",2:"dhruv",3:"aryan"}
print(rollno)
print(rollno[1])
print(rollno.get(2))
rollno.get(4,"not found")
rollno[5] = "rahul"
print(rollno)
# Out:
# {1: 'aman', 2: 'dhruv', 3: 'aryan'}
# aman
# dhruv
# {1: 'aman', 2: 'dhruv', 3: 'aryan', 5: 'rahul'}

# %%
Key Differences:
+: Combines lists into one flat list.
zip(): Creates a list of tuples by pairing elements from both lists.

# %%
#merge 2 list and convert into dict
name = ["aman", "arav", "dhruv", "rahul"]
contact = [1234, 5678, 91011, 121314]
book = dict(zip(name,contact))
print(book)
# Out:
# {'aman': 1234, 'arav': 5678, 'dhruv': 91011, 'rahul': 121314}

# %%
#ADDING ELEMENT IN DICT LIST
book["anand"] = 1357
print(book)
# Out:
# {'aman': 1234, 'arav': 5678, 'dhruv': 91011, 'rahul': 121314, 'anand': 1357}

# %%
#del book["aman"]

# %% [markdown]
# ![image.png](attachment:2a70e2b9-a591-4d5f-b417-9e2bdd2a7834.png)

# %%
class Solution(object):
    def isAnagram(self, s, t):
        a = sorted(s)
        b = sorted(t)
        if a == b:
            return True
        else:
            return False
#takes more time to execute bad time complexity o(nlogn)

# %%
from collections import Counter
class Solution(object):
    def isAnagram(self, s, t):
        a = Counter(s)
        b = Counter(t)
        if a == b:
            return True
        else:
            return False
#takes log(n)

# %% [markdown]
# ![image.png](attachment:9561f41b-1839-474c-8834-26ab9dc2d84a.png)

# %%
class Solution(object):
    def twoSum(self, nums, target):
        for i in range(0,len(nums)):
            for j in range(i+1, len(nums)):
                if nums[i]+nums[j] == target:
                    return i,j #brute force n2

# %%
class Solution(object):
    def twoSum(self, nums, target):
        i = 0
        for i in range(0,len(nums)):
            a = target - nums[i]
            if a in nums[i+1:]:
                return i, nums.index(a,i+1) #best n worst n2

# %%
nums = [1,3,4,5,7,9]
for i,j in enumerate(nums):
    print(i,j)
# Out:
# 0 1
# 1 3
# 2 4
# 3 5
# 4 7
# 5 9

# %%
class Solution(object):
    def twoSum(self, nums, target):
        num_map = {}  
        for i, num in enumerate(nums):  
            complement = target - num
            if complement in num_map:  
                return [num_map[complement], i]
            num_map[num] = i  #O(n)

# %% [markdown]
# ![image.png](attachment:5fe6c05b-82d3-4ca3-86db-7f7b0a7b1550.png)

# %%
import re
class Solution(object):
    def isPalindrome(self, s):
        s = re.sub(r'[^a-zA-Z0-9]','',s).lower()
        d = s[::-1] 
        re.sub(r'[^a-zA-Z0-9]','',s).lower()
        if s == d:
            return True
        else:
            return False

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        newStr = ''
        for c in s:
            if c.isalnum():
                newStr += c.lower()
        return newStr == newStr[::-1] #alt
